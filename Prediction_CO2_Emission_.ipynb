# %%
import pandas as pd

df = pd.read_csv("train.csv")
df
# Out:
#            ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0      ID_-0.510_29.290_2019_00    -0.510     29.290  2019        0
# 1      ID_-0.510_29.290_2019_01    -0.510     29.290  2019        1
# 2      ID_-0.510_29.290_2019_02    -0.510     29.290  2019        2
# 3      ID_-0.510_29.290_2019_03    -0.510     29.290  2019        3
# 4      ID_-0.510_29.290_2019_04    -0.510     29.290  2019        4
# ...                         ...       ...        ...   ...      ...
# 79018  ID_-3.299_30.301_2021_48    -3.299     30.301  2021       48
# 79019  ID_-3.299_30.301_2021_49    -3.299     30.301  2021       49
# 79020  ID_-3.299_30.301_2021_50    -3.299     30.301  2021       50
# 79021  ID_-3.299_30.301_2021_51    -3.299     30.301  2021       51
# 79022  ID_-3.299_30.301_2021_52    -3.299     30.301  2021       52
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                     -0.000108
# 1                                      0.000021
# ...

# %%
Missing_value=df.isnull().sum()/len(df)*100
Missing_value.head(30)
# Out:
# ID_LAT_LON_YEAR_WEEK                                        0.000000
# latitude                                                    0.000000
# longitude                                                   0.000000
# year                                                        0.000000
# week_no                                                     0.000000
# SulphurDioxide_SO2_column_number_density                   18.487023
# SulphurDioxide_SO2_column_number_density_amf               18.487023
# SulphurDioxide_SO2_slant_column_number_density             18.487023
# SulphurDioxide_cloud_fraction                              18.487023
# SulphurDioxide_sensor_azimuth_angle                        18.487023
# SulphurDioxide_sensor_zenith_angle                         18.487023
# SulphurDioxide_solar_azimuth_angle                         18.487023
# SulphurDioxide_solar_zenith_angle                          18.487023
# SulphurDioxide_SO2_column_number_density_15km              18.487023
# ...

# %%
Missing_value.tail(30)
# Out:
# UvAerosolIndex_solar_azimuth_angle             0.682080
# UvAerosolIndex_solar_zenith_angle              0.682080
# Ozone_O3_column_number_density                 0.693469
# Ozone_O3_column_number_density_amf             0.693469
# Ozone_O3_slant_column_number_density           0.693469
# Ozone_O3_effective_temperature                 0.693469
# Ozone_cloud_fraction                           0.693469
# Ozone_sensor_azimuth_angle                     0.693469
# Ozone_sensor_zenith_angle                      0.693469
# Ozone_solar_azimuth_angle                      0.693469
# Ozone_solar_zenith_angle                       0.693469
# UvAerosolLayerHeight_aerosol_height           99.444466
# UvAerosolLayerHeight_aerosol_pressure         99.444466
# UvAerosolLayerHeight_aerosol_optical_depth    99.444466
# UvAerosolLayerHeight_sensor_zenith_angle      99.444466
# UvAerosolLayerHeight_sensor_azimuth_angle     99.444466
# UvAerosolLayerHeight_solar_azimuth_angle      99.444466
# ...

# %%
df=df.drop(['ID_LAT_LON_YEAR_WEEK','year', 'week_no', 'UvAerosolLayerHeight_aerosol_height', 'UvAerosolLayerHeight_aerosol_pressure', 'UvAerosolLayerHeight_aerosol_optical_depth', 'UvAerosolLayerHeight_sensor_zenith_angle', 'UvAerosolLayerHeight_sensor_azimuth_angle', 'UvAerosolLayerHeight_solar_azimuth_angle', 'UvAerosolLayerHeight_solar_zenith_angle'],axis=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79023 entries, 0 to 79022
# Data columns (total 66 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   latitude                                                  79023 non-null  float64
#  1   longitude                                                 79023 non-null  float64
#  2   SulphurDioxide_SO2_column_number_density                  64414 non-null  float64
#  3   SulphurDioxide_SO2_column_number_density_amf              64414 non-null  float64
#  4   SulphurDioxide_SO2_slant_column_number_density            64414 non-null  float64
#  5   SulphurDioxide_cloud_fraction                             64414 non-null  float64
#  6   SulphurDioxide_sensor_azimuth_angle                       64414 non-null  float64
# ...

# %%
df['SulphurDioxide_SO2_column_number_density'] = df[ 'SulphurDioxide_SO2_column_number_density'].fillna(df[ 'SulphurDioxide_SO2_column_number_density'].median())
df['SulphurDioxide_SO2_column_number_density_amf'] = df['SulphurDioxide_SO2_column_number_density_amf'].fillna(df['SulphurDioxide_SO2_column_number_density_amf'].median())
df[ 'SulphurDioxide_SO2_slant_column_number_density'] = df[ 'SulphurDioxide_SO2_slant_column_number_density'].fillna(df[ 'SulphurDioxide_SO2_slant_column_number_density'].median())
df['SulphurDioxide_cloud_fraction'] = df['SulphurDioxide_cloud_fraction'].fillna(df['SulphurDioxide_cloud_fraction'].median())
df[ 'SulphurDioxide_sensor_azimuth_angle'] = df[ 'SulphurDioxide_sensor_azimuth_angle'].fillna(df[ 'SulphurDioxide_sensor_azimuth_angle'].median())
df['SulphurDioxide_sensor_zenith_angle'] = df['SulphurDioxide_sensor_zenith_angle'].fillna(df['SulphurDioxide_sensor_zenith_angle'].median())
df[ 'SulphurDioxide_solar_azimuth_angle'] = df[ 'SulphurDioxide_solar_azimuth_angle'].fillna(df[ 'SulphurDioxide_solar_azimuth_angle'].median())
df['SulphurDioxide_solar_zenith_angle'] = df['SulphurDioxide_solar_zenith_angle'].fillna(df['SulphurDioxide_solar_zenith_angle'].median())
df[ 'SulphurDioxide_SO2_column_number_density_15km'] = df[ 'SulphurDioxide_SO2_column_number_density_15km'].fillna(df[ 'SulphurDioxide_SO2_column_number_density_15km'].median())

df['CarbonMonoxide_CO_column_number_density'] = df['CarbonMonoxide_CO_column_number_density'].fillna(df['CarbonMonoxide_CO_column_number_density'].median())
df[ 'CarbonMonoxide_H2O_column_number_density'] = df[ 'CarbonMonoxide_H2O_column_number_density'].fillna(df[ 'CarbonMonoxide_H2O_column_number_density'].median())
df['CarbonMonoxide_cloud_height'] = df['CarbonMonoxide_cloud_height'].fillna(df['CarbonMonoxide_cloud_height'].median())
df[ 'CarbonMonoxide_sensor_altitude'] = df[ 'CarbonMonoxide_sensor_altitude'].fillna(df[ 'CarbonMonoxide_sensor_altitude'].median())
df[ 'CarbonMonoxide_sensor_azimuth_angle'] = df[ 'CarbonMonoxide_sensor_azimuth_angle'].fillna(df[ 'CarbonMonoxide_sensor_azimuth_angle'].median())
df[ 'CarbonMonoxide_sensor_zenith_angle'] = df[ 'CarbonMonoxide_sensor_zenith_angle'].fillna(df[ 'CarbonMonoxide_sensor_zenith_angle'].median())
df['CarbonMonoxide_solar_azimuth_angle'] = df['CarbonMonoxide_solar_azimuth_angle'].fillna(df['CarbonMonoxide_solar_azimuth_angle'].median())
df[ 'CarbonMonoxide_solar_zenith_angle'] = df[ 'CarbonMonoxide_solar_zenith_angle'].fillna(df[ 'CarbonMonoxide_solar_zenith_angle'].median())



df[ 'NitrogenDioxide_NO2_column_number_density'] = df[ 'NitrogenDioxide_NO2_column_number_density'].fillna(df[ 'NitrogenDioxide_NO2_column_number_density'].median())
df['NitrogenDioxide_tropospheric_NO2_column_number_density'] = df['NitrogenDioxide_tropospheric_NO2_column_number_density'].fillna(df['NitrogenDioxide_tropospheric_NO2_column_number_density'].median())
df[ 'NitrogenDioxide_stratospheric_NO2_column_number_density'] = df[ 'NitrogenDioxide_stratospheric_NO2_column_number_density'].fillna(df[ 'NitrogenDioxide_stratospheric_NO2_column_number_density'].median())
df[ 'NitrogenDioxide_NO2_slant_column_number_density'] =df[ 'NitrogenDioxide_NO2_slant_column_number_density'].fillna(df[ 'NitrogenDioxide_NO2_slant_column_number_density'].median())
df['NitrogenDioxide_tropopause_pressure']=  df['NitrogenDioxide_tropopause_pressure'].fillna(df['NitrogenDioxide_tropopause_pressure'].median())
df[ 'NitrogenDioxide_absorbing_aerosol_index'] = df[ 'NitrogenDioxide_absorbing_aerosol_index'].fillna(df[ 'NitrogenDioxide_absorbing_aerosol_index'].median())
df[ 'NitrogenDioxide_cloud_fraction'] = df[ 'NitrogenDioxide_cloud_fraction'].fillna(df[ 'NitrogenDioxide_cloud_fraction'].median())
df['NitrogenDioxide_sensor_altitude'] =df['NitrogenDioxide_sensor_altitude'].fillna(df['NitrogenDioxide_sensor_altitude'].median())
df[ 'NitrogenDioxide_sensor_azimuth_angle'] = df[ 'NitrogenDioxide_sensor_azimuth_angle'].fillna(df[ 'NitrogenDioxide_sensor_azimuth_angle'].median())                    
df[ 'NitrogenDioxide_sensor_zenith_angle'] = df[ 'NitrogenDioxide_sensor_zenith_angle'].fillna(df[ 'NitrogenDioxide_sensor_zenith_angle'].median())
df[ 'NitrogenDioxide_solar_azimuth_angle'] = df[ 'NitrogenDioxide_solar_azimuth_angle'].fillna(df[ 'NitrogenDioxide_solar_azimuth_angle'].median())
df[ 'NitrogenDioxide_solar_zenith_angle'] = df[ 'NitrogenDioxide_solar_zenith_angle'].fillna(df[ 'NitrogenDioxide_solar_zenith_angle'].median())
         
df[ 'Formaldehyde_tropospheric_HCHO_column_number_density'] = df[ 'Formaldehyde_tropospheric_HCHO_column_number_density'].fillna(df[ 'Formaldehyde_tropospheric_HCHO_column_number_density'].median())        
df[ 'Formaldehyde_tropospheric_HCHO_column_number_density_amf'] = df[ 'Formaldehyde_tropospheric_HCHO_column_number_density_amf'].fillna(df[ 'Formaldehyde_tropospheric_HCHO_column_number_density_amf'].median())
df[ 'Formaldehyde_HCHO_slant_column_number_density'] = df[ 'Formaldehyde_HCHO_slant_column_number_density'].fillna(df[ 'Formaldehyde_HCHO_slant_column_number_density'].median())
df[ 'Formaldehyde_cloud_fraction'] = df[ 'Formaldehyde_cloud_fraction'].fillna(df[ 'Formaldehyde_cloud_fraction'].median())                                  
df[ 'Formaldehyde_solar_zenith_angle'] = df[ 'Formaldehyde_solar_zenith_angle'].fillna(df[ 'Formaldehyde_solar_zenith_angle'].median())
df[ 'Formaldehyde_solar_azimuth_angle']= df[ 'Formaldehyde_solar_azimuth_angle'].fillna(df[ 'Formaldehyde_solar_azimuth_angle'].median())
df[ 'Formaldehyde_sensor_zenith_angle'] = df[ 'Formaldehyde_sensor_zenith_angle'].fillna(df[ 'Formaldehyde_sensor_zenith_angle'].median())
df[ 'Formaldehyde_sensor_azimuth_angle'] = df[ 'Formaldehyde_sensor_azimuth_angle'].fillna(df[ 'Formaldehyde_sensor_azimuth_angle'].median())

df[ 'UvAerosolIndex_absorbing_aerosol_index'] = df[ 'UvAerosolIndex_absorbing_aerosol_index'].fillna(df[ 'UvAerosolIndex_absorbing_aerosol_index'].median())   
df[ 'UvAerosolIndex_sensor_altitude'] = df[ 'UvAerosolIndex_sensor_altitude'].fillna(df[ 'UvAerosolIndex_sensor_altitude'].median())
df[ 'UvAerosolIndex_sensor_azimuth_angle'] = df[ 'UvAerosolIndex_sensor_azimuth_angle'].fillna(df[ 'UvAerosolIndex_sensor_azimuth_angle'].median())
df[ 'UvAerosolIndex_sensor_zenith_angle'] = df[ 'UvAerosolIndex_sensor_zenith_angle'].fillna(df[ 'UvAerosolIndex_sensor_zenith_angle'].median())
df[ 'UvAerosolIndex_solar_azimuth_angle'] = df[ 'UvAerosolIndex_solar_azimuth_angle'].fillna(df[ 'UvAerosolIndex_solar_azimuth_angle'].median())
df[ 'UvAerosolIndex_solar_zenith_angle'] = df[ 'UvAerosolIndex_solar_zenith_angle'].fillna(df[ 'UvAerosolIndex_solar_zenith_angle'].median())

df[ 'Ozone_O3_column_number_density'] = df[ 'Ozone_O3_column_number_density'].fillna(df[ 'Ozone_O3_column_number_density'].median())
df[ 'Ozone_O3_column_number_density_amf'] = df[ 'Ozone_O3_column_number_density_amf'].fillna(df[ 'Ozone_O3_column_number_density_amf'].median())
df[ 'Ozone_O3_slant_column_number_density'] = df[ 'Ozone_O3_slant_column_number_density'].fillna(df[ 'Ozone_O3_slant_column_number_density'].median())
df[ 'Ozone_O3_effective_temperature'] = df[ 'Ozone_O3_effective_temperature'].fillna(df[ 'Ozone_O3_effective_temperature'].median())
df[ 'Ozone_cloud_fraction'] = df[ 'Ozone_cloud_fraction'].fillna(df[ 'Ozone_cloud_fraction'].median())
df[ 'Ozone_sensor_azimuth_angle'] = df[ 'Ozone_sensor_azimuth_angle'].fillna(df[ 'Ozone_sensor_azimuth_angle'].median())
df[ 'Ozone_sensor_zenith_angle'] = df[ 'Ozone_sensor_zenith_angle'].fillna(df[ 'Ozone_sensor_zenith_angle'].median())
df[ 'Ozone_solar_azimuth_angle'] = df[ 'Ozone_solar_azimuth_angle'].fillna(df[ 'Ozone_solar_azimuth_angle'].median())
df[ 'Ozone_solar_zenith_angle'] = df[ 'Ozone_solar_zenith_angle'].fillna(df[ 'Ozone_solar_zenith_angle'].median())

                                                 
df[ 'Cloud_cloud_fraction'] = df[ 'Cloud_cloud_fraction'].fillna(df[ 'Cloud_cloud_fraction'].median())         
df[ 'Cloud_cloud_top_pressure'] = df[ 'Cloud_cloud_top_pressure'].fillna(df[ 'Cloud_cloud_top_pressure'].median())
df[ 'Cloud_cloud_top_height'] = df[ 'Cloud_cloud_top_height'].fillna(df[ 'Cloud_cloud_top_height'].median())
df[ 'Cloud_cloud_base_pressure'] = df[ 'Cloud_cloud_base_pressure'].fillna(df[ 'Cloud_cloud_base_pressure'].median())
df[ 'Cloud_cloud_base_height'] = df[ 'Cloud_cloud_base_height'].fillna(df[ 'Cloud_cloud_base_height'].median())
df[ 'Cloud_cloud_optical_depth'] = df[ 'Cloud_cloud_optical_depth'].fillna(df[ 'Cloud_cloud_optical_depth'].median())
df[ 'Cloud_surface_albedo'] = df[ 'Cloud_surface_albedo'].fillna(df[ 'Cloud_surface_albedo'].median())
df[ 'Cloud_sensor_azimuth_angle'] = df[ 'Cloud_sensor_azimuth_angle'].fillna(df[ 'Cloud_sensor_azimuth_angle'].median())
df[ 'Cloud_sensor_zenith_angle'] = df[ 'Cloud_sensor_zenith_angle'].fillna(df[ 'Cloud_sensor_zenith_angle'].median())
df[ 'Cloud_solar_azimuth_angle'] = df[ 'Cloud_solar_azimuth_angle'].fillna(df[ 'Cloud_solar_azimuth_angle'].median())
df[ 'Cloud_solar_zenith_angle'] = df[ 'Cloud_solar_zenith_angle'].fillna(df[ 'Cloud_solar_zenith_angle'].median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 79023 entries, 0 to 79022
# Data columns (total 66 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   latitude                                                  79023 non-null  float64
#  1   longitude                                                 79023 non-null  float64
#  2   SulphurDioxide_SO2_column_number_density                  79023 non-null  float64
#  3   SulphurDioxide_SO2_column_number_density_amf              79023 non-null  float64
#  4   SulphurDioxide_SO2_slant_column_number_density            79023 non-null  float64
#  5   SulphurDioxide_cloud_fraction                             79023 non-null  float64
#  6   SulphurDioxide_sensor_azimuth_angle                       79023 non-null  float64
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
plt.figure(figsize=(10,20))
df.iloc[:,:].boxplot(vert=0)
plt.show()

# %%
x=df.drop(['emission'],axis=1)
y=df['emission']

# %%
x
# Out:
#        latitude  longitude  SulphurDioxide_SO2_column_number_density  \
# 0        -0.510     29.290                                 -0.000108
# 1        -0.510     29.290                                  0.000021
# 2        -0.510     29.290                                  0.000514
# 3        -0.510     29.290                                  0.000024
# 4        -0.510     29.290                                 -0.000079
# ...         ...        ...                                       ...
# 79018    -3.299     30.301                                  0.000284
# 79019    -3.299     30.301                                  0.000083
# 79020    -3.299     30.301                                  0.000024
# 79021    -3.299     30.301                                 -0.000034
# 79022    -3.299     30.301                                 -0.000091
#
#        SulphurDioxide_SO2_column_number_density_amf  \
# 0                                          0.603019
# ...

# %%
from sklearn.preprocessing import MinMaxScaler
ms=MinMaxScaler()
x.iloc[:,[4,6,7,8,9]]=ms.fit_transform(x.iloc[:,[4,6,7,8,9]])

# %%
x
# Out:
#        latitude  longitude  SulphurDioxide_SO2_column_number_density  \
# 0        -0.510     29.290                                 -0.000108
# 1        -0.510     29.290                                  0.000021
# 2        -0.510     29.290                                  0.000514
# 3        -0.510     29.290                                  0.000024
# 4        -0.510     29.290                                 -0.000079
# ...         ...        ...                                       ...
# 79018    -3.299     30.301                                  0.000284
# 79019    -3.299     30.301                                  0.000083
# 79020    -3.299     30.301                                  0.000024
# 79021    -3.299     30.301                                 -0.000034
# 79022    -3.299     30.301                                 -0.000091
#
#        SulphurDioxide_SO2_column_number_density_amf  \
# 0                                          0.603019
# ...

# %%
y
# Out:
# 0         3.750994
# 1         4.025176
# 2         4.231381
# 3         4.305286
# 4         4.347317
#            ...
# 79018    29.404171
# 79019    29.186497
# 79020    29.131205
# 79021    28.125792
# 79022    27.239302
# Name: emission, Length: 79023, dtype: float64

# %%
df1 = pd.read_csv("test.csv")
df1
# Out:
#            ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0      ID_-0.510_29.290_2022_00    -0.510     29.290  2022        0
# 1      ID_-0.510_29.290_2022_01    -0.510     29.290  2022        1
# 2      ID_-0.510_29.290_2022_02    -0.510     29.290  2022        2
# 3      ID_-0.510_29.290_2022_03    -0.510     29.290  2022        3
# 4      ID_-0.510_29.290_2022_04    -0.510     29.290  2022        4
# ...                         ...       ...        ...   ...      ...
# 24348  ID_-3.299_30.301_2022_44    -3.299     30.301  2022       44
# 24349  ID_-3.299_30.301_2022_45    -3.299     30.301  2022       45
# 24350  ID_-3.299_30.301_2022_46    -3.299     30.301  2022       46
# 24351  ID_-3.299_30.301_2022_47    -3.299     30.301  2022       47
# 24352  ID_-3.299_30.301_2022_48    -3.299     30.301  2022       48
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                           NaN
# 1                                      0.000456
# ...

# %%
df2=df1.copy()
df2
# Out:
#            ID_LAT_LON_YEAR_WEEK  latitude  longitude  year  week_no  \
# 0      ID_-0.510_29.290_2022_00    -0.510     29.290  2022        0
# 1      ID_-0.510_29.290_2022_01    -0.510     29.290  2022        1
# 2      ID_-0.510_29.290_2022_02    -0.510     29.290  2022        2
# 3      ID_-0.510_29.290_2022_03    -0.510     29.290  2022        3
# 4      ID_-0.510_29.290_2022_04    -0.510     29.290  2022        4
# ...                         ...       ...        ...   ...      ...
# 24348  ID_-3.299_30.301_2022_44    -3.299     30.301  2022       44
# 24349  ID_-3.299_30.301_2022_45    -3.299     30.301  2022       45
# 24350  ID_-3.299_30.301_2022_46    -3.299     30.301  2022       46
# 24351  ID_-3.299_30.301_2022_47    -3.299     30.301  2022       47
# 24352  ID_-3.299_30.301_2022_48    -3.299     30.301  2022       48
#
#        SulphurDioxide_SO2_column_number_density  \
# 0                                           NaN
# 1                                      0.000456
# ...

# %%
Missing_value=df2.isnull().sum()/len(df)*100
Missing_value.head(30)
# Out:
# ID_LAT_LON_YEAR_WEEK                                       0.000000
# latitude                                                   0.000000
# longitude                                                  0.000000
# year                                                       0.000000
# week_no                                                    0.000000
# SulphurDioxide_SO2_column_number_density                   7.772421
# SulphurDioxide_SO2_column_number_density_amf               7.772421
# SulphurDioxide_SO2_slant_column_number_density             7.772421
# SulphurDioxide_cloud_fraction                              7.772421
# SulphurDioxide_sensor_azimuth_angle                        7.772421
# SulphurDioxide_sensor_zenith_angle                         7.772421
# SulphurDioxide_solar_azimuth_angle                         7.772421
# SulphurDioxide_solar_zenith_angle                          7.772421
# SulphurDioxide_SO2_column_number_density_15km              7.772421
# ...

# %%
Missing_value=df2.isnull().sum()/len(df)*100
Missing_value.tail(30)
# Out:
# UvAerosolIndex_sensor_zenith_angle             0.186022
# UvAerosolIndex_solar_azimuth_angle             0.186022
# UvAerosolIndex_solar_zenith_angle              0.186022
# Ozone_O3_column_number_density                 0.186022
# Ozone_O3_column_number_density_amf             0.186022
# Ozone_O3_slant_column_number_density           0.186022
# Ozone_O3_effective_temperature                 0.186022
# Ozone_cloud_fraction                           0.186022
# Ozone_sensor_azimuth_angle                     0.186022
# Ozone_sensor_zenith_angle                      0.186022
# Ozone_solar_azimuth_angle                      0.186022
# Ozone_solar_zenith_angle                       0.186022
# UvAerosolLayerHeight_aerosol_height           28.169014
# UvAerosolLayerHeight_aerosol_pressure         28.169014
# UvAerosolLayerHeight_aerosol_optical_depth    28.169014
# UvAerosolLayerHeight_sensor_zenith_angle      28.169014
# UvAerosolLayerHeight_sensor_azimuth_angle     28.169014
# ...

# %%
df2=df2.drop(['ID_LAT_LON_YEAR_WEEK','year', 'week_no', 'UvAerosolLayerHeight_aerosol_height', 'UvAerosolLayerHeight_aerosol_pressure', 'UvAerosolLayerHeight_aerosol_optical_depth', 'UvAerosolLayerHeight_sensor_zenith_angle', 'UvAerosolLayerHeight_sensor_azimuth_angle', 'UvAerosolLayerHeight_solar_azimuth_angle', 'UvAerosolLayerHeight_solar_zenith_angle'],axis=1)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24353 entries, 0 to 24352
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   latitude                                                  24353 non-null  float64
#  1   longitude                                                 24353 non-null  float64
#  2   SulphurDioxide_SO2_column_number_density                  18211 non-null  float64
#  3   SulphurDioxide_SO2_column_number_density_amf              18211 non-null  float64
#  4   SulphurDioxide_SO2_slant_column_number_density            18211 non-null  float64
#  5   SulphurDioxide_cloud_fraction                             18211 non-null  float64
#  6   SulphurDioxide_sensor_azimuth_angle                       18211 non-null  float64
# ...

# %%
df2['SulphurDioxide_SO2_column_number_density'] = df2[ 'SulphurDioxide_SO2_column_number_density'].fillna(df2[ 'SulphurDioxide_SO2_column_number_density'].median())
df2['SulphurDioxide_SO2_column_number_density_amf'] = df2['SulphurDioxide_SO2_column_number_density_amf'].fillna(df2['SulphurDioxide_SO2_column_number_density_amf'].median())
df2[ 'SulphurDioxide_SO2_slant_column_number_density'] = df2[ 'SulphurDioxide_SO2_slant_column_number_density'].fillna(df2[ 'SulphurDioxide_SO2_slant_column_number_density'].median())
df2['SulphurDioxide_cloud_fraction'] = df2['SulphurDioxide_cloud_fraction'].fillna(df2['SulphurDioxide_cloud_fraction'].median())
df2[ 'SulphurDioxide_sensor_azimuth_angle'] = df2[ 'SulphurDioxide_sensor_azimuth_angle'].fillna(df2[ 'SulphurDioxide_sensor_azimuth_angle'].median())
df2['SulphurDioxide_sensor_zenith_angle'] = df2['SulphurDioxide_sensor_zenith_angle'].fillna(df2['SulphurDioxide_sensor_zenith_angle'].median())
df2[ 'SulphurDioxide_solar_azimuth_angle'] = df2[ 'SulphurDioxide_solar_azimuth_angle'].fillna(df2[ 'SulphurDioxide_solar_azimuth_angle'].median())
df2['SulphurDioxide_solar_zenith_angle'] = df2['SulphurDioxide_solar_zenith_angle'].fillna(df2['SulphurDioxide_solar_zenith_angle'].median())
df2[ 'SulphurDioxide_SO2_column_number_density_15km'] = df2[ 'SulphurDioxide_SO2_column_number_density_15km'].fillna(df2[ 'SulphurDioxide_SO2_column_number_density_15km'].median())

df2['CarbonMonoxide_CO_column_number_density'] = df2['CarbonMonoxide_CO_column_number_density'].fillna(df2['CarbonMonoxide_CO_column_number_density'].median())
df2[ 'CarbonMonoxide_H2O_column_number_density'] = df2[ 'CarbonMonoxide_H2O_column_number_density'].fillna(df2[ 'CarbonMonoxide_H2O_column_number_density'].median())
df2['CarbonMonoxide_cloud_height'] = df2['CarbonMonoxide_cloud_height'].fillna(df2['CarbonMonoxide_cloud_height'].median())
df2[ 'CarbonMonoxide_sensor_altitude'] = df2[ 'CarbonMonoxide_sensor_altitude'].fillna(df[ 'CarbonMonoxide_sensor_altitude'].median())
df2[ 'CarbonMonoxide_sensor_azimuth_angle'] = df2[ 'CarbonMonoxide_sensor_azimuth_angle'].fillna(df2[ 'CarbonMonoxide_sensor_azimuth_angle'].median())
df2[ 'CarbonMonoxide_sensor_zenith_angle'] = df2[ 'CarbonMonoxide_sensor_zenith_angle'].fillna(df2[ 'CarbonMonoxide_sensor_zenith_angle'].median())
df2['CarbonMonoxide_solar_azimuth_angle'] = df2['CarbonMonoxide_solar_azimuth_angle'].fillna(df2['CarbonMonoxide_solar_azimuth_angle'].median())
df2[ 'CarbonMonoxide_solar_zenith_angle'] = df2[ 'CarbonMonoxide_solar_zenith_angle'].fillna(df2[ 'CarbonMonoxide_solar_zenith_angle'].median())



df2[ 'NitrogenDioxide_NO2_column_number_density'] = df2[ 'NitrogenDioxide_NO2_column_number_density'].fillna(df2[ 'NitrogenDioxide_NO2_column_number_density'].median())
df2['NitrogenDioxide_tropospheric_NO2_column_number_density'] = df2['NitrogenDioxide_tropospheric_NO2_column_number_density'].fillna(df2['NitrogenDioxide_tropospheric_NO2_column_number_density'].median())
df2[ 'NitrogenDioxide_stratospheric_NO2_column_number_density'] = df2[ 'NitrogenDioxide_stratospheric_NO2_column_number_density'].fillna(df2[ 'NitrogenDioxide_stratospheric_NO2_column_number_density'].median())
df2[ 'NitrogenDioxide_NO2_slant_column_number_density'] =df2[ 'NitrogenDioxide_NO2_slant_column_number_density'].fillna(df2[ 'NitrogenDioxide_NO2_slant_column_number_density'].median())
df2['NitrogenDioxide_tropopause_pressure']=  df2['NitrogenDioxide_tropopause_pressure'].fillna(df2['NitrogenDioxide_tropopause_pressure'].median())
df2[ 'NitrogenDioxide_absorbing_aerosol_index'] = df2[ 'NitrogenDioxide_absorbing_aerosol_index'].fillna(df2[ 'NitrogenDioxide_absorbing_aerosol_index'].median())
df2[ 'NitrogenDioxide_cloud_fraction'] = df2[ 'NitrogenDioxide_cloud_fraction'].fillna(df2[ 'NitrogenDioxide_cloud_fraction'].median())
df2['NitrogenDioxide_sensor_altitude'] =df2['NitrogenDioxide_sensor_altitude'].fillna(df2['NitrogenDioxide_sensor_altitude'].median())
df2[ 'NitrogenDioxide_sensor_azimuth_angle'] = df2[ 'NitrogenDioxide_sensor_azimuth_angle'].fillna(df2[ 'NitrogenDioxide_sensor_azimuth_angle'].median())                    
df2[ 'NitrogenDioxide_sensor_zenith_angle'] = df2[ 'NitrogenDioxide_sensor_zenith_angle'].fillna(df2[ 'NitrogenDioxide_sensor_zenith_angle'].median())
df2[ 'NitrogenDioxide_solar_azimuth_angle'] = df2[ 'NitrogenDioxide_solar_azimuth_angle'].fillna(df2[ 'NitrogenDioxide_solar_azimuth_angle'].median())
df2[ 'NitrogenDioxide_solar_zenith_angle'] = df2[ 'NitrogenDioxide_solar_zenith_angle'].fillna(df2[ 'NitrogenDioxide_solar_zenith_angle'].median())
         
df2[ 'Formaldehyde_tropospheric_HCHO_column_number_density'] = df2[ 'Formaldehyde_tropospheric_HCHO_column_number_density'].fillna(df2[ 'Formaldehyde_tropospheric_HCHO_column_number_density'].median())        
df2[ 'Formaldehyde_tropospheric_HCHO_column_number_density_amf'] = df2[ 'Formaldehyde_tropospheric_HCHO_column_number_density_amf'].fillna(df2[ 'Formaldehyde_tropospheric_HCHO_column_number_density_amf'].median())
df2[ 'Formaldehyde_HCHO_slant_column_number_density'] = df2[ 'Formaldehyde_HCHO_slant_column_number_density'].fillna(df2[ 'Formaldehyde_HCHO_slant_column_number_density'].median())
df2[ 'Formaldehyde_cloud_fraction'] = df2[ 'Formaldehyde_cloud_fraction'].fillna(df2[ 'Formaldehyde_cloud_fraction'].median())                                  
df2[ 'Formaldehyde_solar_zenith_angle'] = df2[ 'Formaldehyde_solar_zenith_angle'].fillna(df2[ 'Formaldehyde_solar_zenith_angle'].median())
df2[ 'Formaldehyde_solar_azimuth_angle']= df2[ 'Formaldehyde_solar_azimuth_angle'].fillna(df2[ 'Formaldehyde_solar_azimuth_angle'].median())
df2[ 'Formaldehyde_sensor_zenith_angle'] = df2[ 'Formaldehyde_sensor_zenith_angle'].fillna(df2[ 'Formaldehyde_sensor_zenith_angle'].median())
df2[ 'Formaldehyde_sensor_azimuth_angle'] = df2[ 'Formaldehyde_sensor_azimuth_angle'].fillna(df2[ 'Formaldehyde_sensor_azimuth_angle'].median())

df2[ 'UvAerosolIndex_absorbing_aerosol_index'] = df2[ 'UvAerosolIndex_absorbing_aerosol_index'].fillna(df2[ 'UvAerosolIndex_absorbing_aerosol_index'].median())   
df2[ 'UvAerosolIndex_sensor_altitude'] = df2[ 'UvAerosolIndex_sensor_altitude'].fillna(df2[ 'UvAerosolIndex_sensor_altitude'].median())
df2[ 'UvAerosolIndex_sensor_azimuth_angle'] = df2[ 'UvAerosolIndex_sensor_azimuth_angle'].fillna(df2[ 'UvAerosolIndex_sensor_azimuth_angle'].median())
df2[ 'UvAerosolIndex_sensor_zenith_angle'] = df2[ 'UvAerosolIndex_sensor_zenith_angle'].fillna(df2[ 'UvAerosolIndex_sensor_zenith_angle'].median())
df2[ 'UvAerosolIndex_solar_azimuth_angle'] = df2[ 'UvAerosolIndex_solar_azimuth_angle'].fillna(df2[ 'UvAerosolIndex_solar_azimuth_angle'].median())
df2[ 'UvAerosolIndex_solar_zenith_angle'] = df2[ 'UvAerosolIndex_solar_zenith_angle'].fillna(df2[ 'UvAerosolIndex_solar_zenith_angle'].median())

df2[ 'Ozone_O3_column_number_density'] = df2[ 'Ozone_O3_column_number_density'].fillna(df2[ 'Ozone_O3_column_number_density'].median())
df2[ 'Ozone_O3_column_number_density_amf'] = df2[ 'Ozone_O3_column_number_density_amf'].fillna(df2[ 'Ozone_O3_column_number_density_amf'].median())
df2[ 'Ozone_O3_slant_column_number_density'] = df2[ 'Ozone_O3_slant_column_number_density'].fillna(df2[ 'Ozone_O3_slant_column_number_density'].median())
df2[ 'Ozone_O3_effective_temperature'] = df2[ 'Ozone_O3_effective_temperature'].fillna(df2[ 'Ozone_O3_effective_temperature'].median())
df2[ 'Ozone_cloud_fraction'] = df2[ 'Ozone_cloud_fraction'].fillna(df2[ 'Ozone_cloud_fraction'].median())
df2[ 'Ozone_sensor_azimuth_angle'] = df2[ 'Ozone_sensor_azimuth_angle'].fillna(df2[ 'Ozone_sensor_azimuth_angle'].median())
df2[ 'Ozone_sensor_zenith_angle'] = df2[ 'Ozone_sensor_zenith_angle'].fillna(df2[ 'Ozone_sensor_zenith_angle'].median())
df2[ 'Ozone_solar_azimuth_angle'] = df2[ 'Ozone_solar_azimuth_angle'].fillna(df2[ 'Ozone_solar_azimuth_angle'].median())
df2[ 'Ozone_solar_zenith_angle'] = df2[ 'Ozone_solar_zenith_angle'].fillna(df2[ 'Ozone_solar_zenith_angle'].median())

                                                  
df2[ 'Cloud_cloud_fraction'] = df2[ 'Cloud_cloud_fraction'].fillna(df2[ 'Cloud_cloud_fraction'].median())         
df2[ 'Cloud_cloud_top_pressure'] = df2[ 'Cloud_cloud_top_pressure'].fillna(df2[ 'Cloud_cloud_top_pressure'].median())
df2[ 'Cloud_cloud_top_height'] = df2[ 'Cloud_cloud_top_height'].fillna(df2[ 'Cloud_cloud_top_height'].median())
df2[ 'Cloud_cloud_base_pressure'] = df2[ 'Cloud_cloud_base_pressure'].fillna(df2[ 'Cloud_cloud_base_pressure'].median())
df2[ 'Cloud_cloud_base_height'] = df2[ 'Cloud_cloud_base_height'].fillna(df2[ 'Cloud_cloud_base_height'].median())
df2[ 'Cloud_cloud_optical_depth'] = df2[ 'Cloud_cloud_optical_depth'].fillna(df2[ 'Cloud_cloud_optical_depth'].median())
df2[ 'Cloud_surface_albedo'] = df2[ 'Cloud_surface_albedo'].fillna(df2[ 'Cloud_surface_albedo'].median())
df2[ 'Cloud_sensor_azimuth_angle'] = df2[ 'Cloud_sensor_azimuth_angle'].fillna(df2[ 'Cloud_sensor_azimuth_angle'].median())
df2[ 'Cloud_sensor_zenith_angle'] = df2[ 'Cloud_sensor_zenith_angle'].fillna(df2[ 'Cloud_sensor_zenith_angle'].median())
df2[ 'Cloud_solar_azimuth_angle'] = df2[ 'Cloud_solar_azimuth_angle'].fillna(df2[ 'Cloud_solar_azimuth_angle'].median())
df2[ 'Cloud_solar_zenith_angle'] = df2[ 'Cloud_solar_zenith_angle'].fillna(df2[ 'Cloud_solar_zenith_angle'].median())

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24353 entries, 0 to 24352
# Data columns (total 65 columns):
#  #   Column                                                    Non-Null Count  Dtype
# ---  ------                                                    --------------  -----
#  0   latitude                                                  24353 non-null  float64
#  1   longitude                                                 24353 non-null  float64
#  2   SulphurDioxide_SO2_column_number_density                  24353 non-null  float64
#  3   SulphurDioxide_SO2_column_number_density_amf              24353 non-null  float64
#  4   SulphurDioxide_SO2_slant_column_number_density            24353 non-null  float64
#  5   SulphurDioxide_cloud_fraction                             24353 non-null  float64
#  6   SulphurDioxide_sensor_azimuth_angle                       24353 non-null  float64
# ...

# %%
df2.iloc[:,[4,6,7,8,9]]=ms.fit_transform(df2.iloc[:,[4,6,7,8,9]])

# %%
# !pip install catboost
from sklearn.linear_model import LinearRegression,LogisticRegression
from sklearn.ensemble import GradientBoostingRegressor
from catboost import CatBoostRegressor



reg=CatBoostRegressor()
reg.fit(x,y)
reg.score(x,y)
# Out:
# ...
# Learning rate set to 0.081663
# 0:	learn: 138.3350073	total: 180ms	remaining: 2m 59s
# 1:	learn: 133.1475575	total: 208ms	remaining: 1m 43s
# 2:	learn: 128.5203579	total: 233ms	remaining: 1m 17s
# 3:	learn: 124.6207289	total: 256ms	remaining: 1m 3s
# 4:	learn: 119.6778813	total: 281ms	remaining: 55.8s
# 5:	learn: 116.3649945	total: 303ms	remaining: 50.1s
# 6:	learn: 113.4963217	total: 324ms	remaining: 46s
# 7:	learn: 111.0394414	total: 346ms	remaining: 42.9s
# 8:	learn: 109.7852144	total: 370ms	remaining: 40.7s
# 9:	learn: 107.2383148	total: 403ms	remaining: 39.9s
# 10:	learn: 105.4057896	total: 428ms	remaining: 38.5s
# 11:	learn: 103.7195186	total: 450ms	remaining: 37.1s
# 12:	learn: 102.8660616	total: 473ms	remaining: 35.9s
# 13:	learn: 100.8483663	total: 497ms	remaining: 35s
# 14:	learn: 99.9759782	total: 518ms	remaining: 34s
# 15:	learn: 99.2536386	total: 539ms	remaining: 33.1s
# 16:	learn: 98.0124330	total: 560ms	remaining: 32.4s
# ...

# %%
ypred=reg.predict(x)

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y,ypred,squared=False)
# Out:
# 26.949543975265314

# %%
df2['emission'] = reg.predict(df2)

# %%
df2['emission']
# Out:
# 0        13.705571
# 1        -4.814638
# 2        11.041360
# 3         6.306738
# 4        -1.837357
#            ...
# 24348    40.547101
# 24349    48.125175
# 24350    27.014396
# 24351    19.717485
# 24352    30.490097
# Name: emission, Length: 24353, dtype: float64

# %%
df2
# Out:
#        latitude  longitude  SulphurDioxide_SO2_column_number_density  \
# 0        -0.510     29.290                                  0.000007
# 1        -0.510     29.290                                  0.000456
# 2        -0.510     29.290                                  0.000161
# 3        -0.510     29.290                                  0.000350
# 4        -0.510     29.290                                 -0.000317
# ...         ...        ...                                       ...
# 24348    -3.299     30.301                                 -0.000618
# 24349    -3.299     30.301                                  0.000007
# 24350    -3.299     30.301                                  0.000007
# 24351    -3.299     30.301                                  0.000071
# 24352    -3.299     30.301                                  0.000007
#
#        SulphurDioxide_SO2_column_number_density_amf  \
# 0                                          0.763307
# ...

# %%
emission_df = df2[['emission']]
emission_df
# Out:
#         emission
# 0      13.705571
# 1      -4.814638
# 2      11.041360
# 3       6.306738
# 4      -1.837357
# ...          ...
# 24348  40.547101
# 24349  48.125175
# 24350  27.014396
# 24351  19.717485
# 24352  30.490097
#
# [24353 rows x 1 columns]

# %%
one_d_array = emission_df.reshape(-1)
emission_df = pd.DataFrame({'emission': one_d_array})
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 one_d_array = emission_df.reshape(-1)
#       2 emission_df = pd.DataFrame({'emission': one_d_array})
#
# File ~\anaconda3\lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'reshape'

# %%
emission_df.to_excel('output2.xlsx', index = False)

# %%
emission_df.to_csv('output2.csv', index = False)
